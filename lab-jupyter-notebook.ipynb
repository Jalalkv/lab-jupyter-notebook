# %% [markdown]
# # Imaginary Holiday

# %% [markdown]
# In the notebook that you created, introduce someone and her/his holidays preference with a picture and a link to a youtube video of this holiday preference .

# %% [markdown]
# ![istockphoto-1160947136-612x612.jpg](attachment:istockphoto-1160947136-612x612.jpg)

# %% [markdown]
# __[Youtube Link](https://www.youtube.com/watch?v=9GvTYd5hG_g)__

# %% [markdown]
# Include an index to the relevant sections of your notebook

# %% [markdown]
# Write a function that inputs the user's name (You or a friend)

# %%
Name = input('Please enter your name:')

# %% [markdown]
# Add a photo of you or that friend.

# %% [markdown]
# ![istockphoto-1212602712-1024x1024%20%281%29.jpg](attachment:istockphoto-1212602712-1024x1024%20%281%29.jpg)

# %% [markdown]
# Write a function that inputs their holidays preference.

# %%
holiday_preference = input ('Please enter your holiday preference:')

# %% [markdown]
# Add bullet points of the top 3 things that you or your friend like doing in this destination.

# %% [markdown]
# - Swimming
# - Sightseeing
# - Drinking and Drinking

# %% [markdown]
# Try to make the text colorful, bold or italic.

# %% [markdown]
# <i> Lets go to holiday
#
# <b> Lets go to holiday
